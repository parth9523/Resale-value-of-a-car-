# %%
import pandas as pd

# %%
df2 = pd.read_csv('Carsales.csv')
df2
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df3 = df2.rename(columns={'__year_resale_value':'resale_value'})
df3
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df4=df3.rename(columns={'Sales_in_thousands':'Sales'})
df4
# Out:
#     Manufacturer    Model   Sales  resale_value Vehicle_type  \
# 0          Acura  Integra  16.919        16.360    Passenger
# 1          Acura       TL  39.384        19.875    Passenger
# 2          Acura       CL  14.114        18.225    Passenger
# 3          Acura       RL   8.588        29.725    Passenger
# 4           Audi       A4  20.397        22.255    Passenger
# ..           ...      ...     ...           ...          ...
# 152        Volvo      V40   3.545           NaN    Passenger
# 153        Volvo      S70  15.245           NaN    Passenger
# 154        Volvo      V70  17.531           NaN    Passenger
# 155        Volvo      C70   3.493           NaN    Passenger
# 156        Volvo      S80  18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
df5 = df4[['Sales','Horsepower','resale_value']].fillna(0)
df5
# Out:
#       Sales  Horsepower  resale_value
# 0    16.919       140.0        16.360
# 1    39.384       225.0        19.875
# 2    14.114       225.0        18.225
# 3     8.588       210.0        29.725
# 4    20.397       150.0        22.255
# ..      ...         ...           ...
# 152   3.545       160.0         0.000
# 153  15.245       168.0         0.000
# 154  17.531       168.0         0.000
# 155   3.493       236.0         0.000
# 156  18.969       201.0         0.000
#
# [157 rows x 3 columns]

# %%
df5 = df4[['Sales','Horsepower','resale_value']].fillna(0)
df5
# Out:
#       Sales  Horsepower  resale_value
# 0    16.919       140.0        16.360
# 1    39.384       225.0        19.875
# 2    14.114       225.0        18.225
# 3     8.588       210.0        29.725
# 4    20.397       150.0        22.255
# ..      ...         ...           ...
# 152   3.545       160.0         0.000
# 153  15.245       168.0         0.000
# 154  17.531       168.0         0.000
# 155   3.493       236.0         0.000
# 156  18.969       201.0         0.000
#
# [157 rows x 3 columns]

# %%
df5 = df5[['Sales','Horsepower','resale_value']].astype(int)
df5
# Out:
#      Sales  Horsepower  resale_value
# 0       16         140            16
# 1       39         225            19
# 2       14         225            18
# 3        8         210            29
# 4       20         150            22
# ..     ...         ...           ...
# 152      3         160             0
# 153     15         168             0
# 154     17         168             0
# 155      3         236             0
# 156     18         201             0
#
# [157 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
df3
X = df5.drop(columns='resale_value')
y = df5['resale_value']
model = DecisionTreeClassifier()
model.fit(X,y)
prediction=model.predict([[16,140]])
prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([16])
